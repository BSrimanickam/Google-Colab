# %%
for (i in 1:20){
  print("Tamil")
}
# Out:
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"

# %%
for (i in 1:20){
  print("Tamil")
}
# Out:
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"
# [1] "Tamil"

# %%
Speed <- cars$speed
Distance <- cars$dist
plot(Speed, Distance, panel.first = grid(8, 8),
     pch = 0, cex = 1.2, col = "green")
plot(Speed, Distance,
     panel.first = lines(stats::lowess(Speed, Distance), lty = "dashed"),
     pch = 0, cex = 1.2, col = "green")
# Out:
# plot without title
# plot without title
